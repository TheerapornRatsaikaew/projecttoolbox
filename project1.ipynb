# %% [markdown]
# <a href="https://colab.research.google.com/github/TheerapornRatsaikaew/projecttoolbox/blob/main/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
unzip = zipfile.ZipFile("/content/PFData2.zip", 'r')
unzip.extractall('data')

# %%
import pandas as pd
import pandasql

# %%
#!pip install pandas

# %%
#!pip install pandasql

# %%
csvdf = pd.read_csv('/content/data/การเสริมสร้างภูมิคุ้มกัน.csv')

# %%
csvdf.shape
# Out:
# (114, 20)

# %%
csvdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 20 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   ประทับเวลา                                                                            114 non-null    object
#  1   1. เพศ                                                                                113 non-null    object
#  2   2. อายุ                                                                               113 non-null    object
#  3   ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ทานอาหารตามหลักโภชนาการ]                               112 non-null    object
#  4   ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ดื่มน้ำเปล่าเพียงพอต่อความต้องการของร่างกาย]           112 non-null    object
# ...

# %%
csvdf.isnull().sum() #
# Out:
# ประทับเวลา                                                                                0
# 1. เพศ                                                                                    1
# 2. อายุ                                                                                   1
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ทานอาหารตามหลักโภชนาการ]                                   2
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ดื่มน้ำเปล่าเพียงพอต่อความต้องการของร่างกาย]               2
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [สูบบุหรี่หรือยาเส้น]                                       4
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ดื่มแอลกอฮอล์หรือของมึนเมา]                                3
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [คุณมีวิธีการจัดการกับความเครียด]                           2
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ล้างมือด้วยสบู่หลังการขับถ่าย]                             2
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [การตรวจสุขภาพประจำปี]                                      2
# ...

# %%
csvdf.head()
# Out:
#                              ประทับเวลา 1. เพศ  ... Unnamed: 18 Unnamed: 19
# 0  2564/08/10 11:19:06 หลังเที่ยง GMT+7   หญิง  ...   น้อยครั้ง      ไม่เคย
# 1  2564/08/10 11:27:26 หลังเที่ยง GMT+7   หญิง  ...    บางครั้ง   น้อยครั้ง
# 2  2564/08/11 12:22:16 หลังเที่ยง GMT+7    ชาย  ...         NaN         NaN
# 3  2564/08/11 12:36:03 หลังเที่ยง GMT+7    ชาย  ...         NaN         NaN
# 4  2564/08/11 12:42:27 หลังเที่ยง GMT+7    ชาย  ...         NaN         NaN
#
# [5 rows x 20 columns]

# %%
csvdf = csvdf.drop(1, axis=0)
csvdf.reset_index(drop=True) # Reset index
# Out:
#                                ประทับเวลา 1. เพศ  ... Unnamed: 18 Unnamed: 19
# 0    2564/08/10 11:19:06 หลังเที่ยง GMT+7   หญิง  ...   น้อยครั้ง      ไม่เคย
# 1    2564/08/11 12:22:16 หลังเที่ยง GMT+7    ชาย  ...         NaN         NaN
# 2    2564/08/11 12:36:03 หลังเที่ยง GMT+7    ชาย  ...         NaN         NaN
# 3    2564/08/11 12:42:27 หลังเที่ยง GMT+7    ชาย  ...         NaN         NaN
# 4     2564/08/11 1:12:03 หลังเที่ยง GMT+7   หญิง  ...         NaN         NaN
# ..                                    ...    ...  ...         ...         ...
# 108   2564/08/18 9:14:20 หลังเที่ยง GMT+7   หญิง  ...         NaN         NaN
# 109   2564/08/18 9:35:16 หลังเที่ยง GMT+7    NaN  ...         NaN         NaN
# 110  2564/08/18 10:15:36 หลังเที่ยง GMT+7   หญิง  ...         NaN         NaN
# 111   2564/08/19 9:36:02 ก่อนเที่ยง GMT+7   หญิง  ...         NaN         NaN
# 112  2564/08/19 10:33:49 ก่อนเที่ยง GMT+7   หญิง  ...         NaN         NaN
#
# [113 rows x 20 columns]

# %%
csvdf = csvdf.drop(0, axis=0)
csvdf.reset_index(drop=True) # Reset index
# Out:
#                                ประทับเวลา 1. เพศ  ... Unnamed: 18 Unnamed: 19
# 0    2564/08/11 12:22:16 หลังเที่ยง GMT+7    ชาย  ...         NaN         NaN
# 1    2564/08/11 12:36:03 หลังเที่ยง GMT+7    ชาย  ...         NaN         NaN
# 2    2564/08/11 12:42:27 หลังเที่ยง GMT+7    ชาย  ...         NaN         NaN
# 3     2564/08/11 1:12:03 หลังเที่ยง GMT+7   หญิง  ...         NaN         NaN
# 4     2564/08/11 1:16:49 หลังเที่ยง GMT+7   หญิง  ...         NaN         NaN
# ..                                    ...    ...  ...         ...         ...
# 107   2564/08/18 9:14:20 หลังเที่ยง GMT+7   หญิง  ...         NaN         NaN
# 108   2564/08/18 9:35:16 หลังเที่ยง GMT+7    NaN  ...         NaN         NaN
# 109  2564/08/18 10:15:36 หลังเที่ยง GMT+7   หญิง  ...         NaN         NaN
# 110   2564/08/19 9:36:02 ก่อนเที่ยง GMT+7   หญิง  ...         NaN         NaN
# 111  2564/08/19 10:33:49 ก่อนเที่ยง GMT+7   หญิง  ...         NaN         NaN
#
# [112 rows x 20 columns]

# %%
csvdf = csvdf.drop('Unnamed: 16', axis=1)
csvdf = csvdf.drop('Unnamed: 17', axis=1)
csvdf = csvdf.drop('Unnamed: 18', axis=1)
csvdf = csvdf.drop('Unnamed: 19', axis=1)

# %%
csvdf.head(120)
# Out:
#                                ประทับเวลา  ...  2. ประเภทการออกกำลังกาย
# 2    2564/08/11 12:22:16 หลังเที่ยง GMT+7  ...                     วิ่ง
# 3    2564/08/11 12:36:03 หลังเที่ยง GMT+7  ...                     วิ่ง
# 4    2564/08/11 12:42:27 หลังเที่ยง GMT+7  ...                      นอน
# 5     2564/08/11 1:12:03 หลังเที่ยง GMT+7  ...              เต้นแอโรบิค
# 6     2564/08/11 1:16:49 หลังเที่ยง GMT+7  ...              ปั่นจักรยาน
# ..                                    ...  ...                      ...
# 109   2564/08/18 9:14:20 หลังเที่ยง GMT+7  ...  แบดมินตัน/เทนนิส/ปิงปอง
# 110   2564/08/18 9:35:16 หลังเที่ยง GMT+7  ...        ยกน้ำหนัก/เล่นเวท
# 111  2564/08/18 10:15:36 หลังเที่ยง GMT+7  ...                     โยคะ
# 112   2564/08/19 9:36:02 ก่อนเที่ยง GMT+7  ...                     วิ่ง
# 113  2564/08/19 10:33:49 ก่อนเที่ยง GMT+7  ...                  ซิดอ้ัพ
#
# [112 rows x 16 columns]

# %%
csvdf.isnull().sum()
# Out:
# ประทับเวลา                                                                              0
# 1. เพศ                                                                                  1
# 2. อายุ                                                                                 1
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ทานอาหารตามหลักโภชนาการ]                                 0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ดื่มน้ำเปล่าเพียงพอต่อความต้องการของร่างกาย]             0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [สูบบุหรี่หรือยาเส้น]                                     2
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ดื่มแอลกอฮอล์หรือของมึนเมา]                              1
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [คุณมีวิธีการจัดการกับความเครียด]                         0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ล้างมือด้วยสบู่หลังการขับถ่าย]                           0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [การตรวจสุขภาพประจำปี]                                    0
# ...

# %%
csvdf['1. เพศ'].fillna('หญิง',inplace=True) #แปลง NaN เป็น

# %%
csvdf['2. อายุ'].fillna('21-25 ปี',inplace=True) #แปลง NaN เป็น

# %%
csvdf.isnull().sum()
# Out:
# ประทับเวลา                                                                              0
# 1. เพศ                                                                                  0
# 2. อายุ                                                                                 0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ทานอาหารตามหลักโภชนาการ]                                 0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ดื่มน้ำเปล่าเพียงพอต่อความต้องการของร่างกาย]             0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [สูบบุหรี่หรือยาเส้น]                                     2
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ดื่มแอลกอฮอล์หรือของมึนเมา]                              1
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [คุณมีวิธีการจัดการกับความเครียด]                         0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ล้างมือด้วยสบู่หลังการขับถ่าย]                           0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [การตรวจสุขภาพประจำปี]                                    0
# ...

# %%
csvdf = csvdf.drop(22, axis=0)
csvdf.reset_index(drop=True) # Reset index
# Out:
#                                ประทับเวลา  ...  2. ประเภทการออกกำลังกาย
# 0    2564/08/11 12:22:16 หลังเที่ยง GMT+7  ...                     วิ่ง
# 1    2564/08/11 12:36:03 หลังเที่ยง GMT+7  ...                     วิ่ง
# 2    2564/08/11 12:42:27 หลังเที่ยง GMT+7  ...                      นอน
# 3     2564/08/11 1:12:03 หลังเที่ยง GMT+7  ...              เต้นแอโรบิค
# 4     2564/08/11 1:16:49 หลังเที่ยง GMT+7  ...              ปั่นจักรยาน
# ..                                    ...  ...                      ...
# 106   2564/08/18 9:14:20 หลังเที่ยง GMT+7  ...  แบดมินตัน/เทนนิส/ปิงปอง
# 107   2564/08/18 9:35:16 หลังเที่ยง GMT+7  ...        ยกน้ำหนัก/เล่นเวท
# 108  2564/08/18 10:15:36 หลังเที่ยง GMT+7  ...                     โยคะ
# 109   2564/08/19 9:36:02 ก่อนเที่ยง GMT+7  ...                     วิ่ง
# 110  2564/08/19 10:33:49 ก่อนเที่ยง GMT+7  ...                  ซิดอ้ัพ
#
# [111 rows x 16 columns]

# %%
csvdf = csvdf.drop(39, axis=0)
csvdf.reset_index(drop=True) # Reset index
# Out:
#                                ประทับเวลา  ...  2. ประเภทการออกกำลังกาย
# 0    2564/08/11 12:22:16 หลังเที่ยง GMT+7  ...                     วิ่ง
# 1    2564/08/11 12:36:03 หลังเที่ยง GMT+7  ...                     วิ่ง
# 2    2564/08/11 12:42:27 หลังเที่ยง GMT+7  ...                      นอน
# 3     2564/08/11 1:12:03 หลังเที่ยง GMT+7  ...              เต้นแอโรบิค
# 4     2564/08/11 1:16:49 หลังเที่ยง GMT+7  ...              ปั่นจักรยาน
# ..                                    ...  ...                      ...
# 105   2564/08/18 9:14:20 หลังเที่ยง GMT+7  ...  แบดมินตัน/เทนนิส/ปิงปอง
# 106   2564/08/18 9:35:16 หลังเที่ยง GMT+7  ...        ยกน้ำหนัก/เล่นเวท
# 107  2564/08/18 10:15:36 หลังเที่ยง GMT+7  ...                     โยคะ
# 108   2564/08/19 9:36:02 ก่อนเที่ยง GMT+7  ...                     วิ่ง
# 109  2564/08/19 10:33:49 ก่อนเที่ยง GMT+7  ...                  ซิดอ้ัพ
#
# [110 rows x 16 columns]

# %%
csvdf.to_csv('ทดสอบภูมิคุ้มกัน.csv')

# %%
csvdf.isnull().sum()
# Out:
# ประทับเวลา                                                                              0
# 1. เพศ                                                                                  0
# 2. อายุ                                                                                 0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ทานอาหารตามหลักโภชนาการ]                                 0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ดื่มน้ำเปล่าเพียงพอต่อความต้องการของร่างกาย]             0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [สูบบุหรี่หรือยาเส้น]                                     0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ดื่มแอลกอฮอล์หรือของมึนเมา]                              0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [คุณมีวิธีการจัดการกับความเครียด]                         0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ล้างมือด้วยสบู่หลังการขับถ่าย]                           0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [การตรวจสุขภาพประจำปี]                                    0
# ...

# %%
csvdf['2. ประเภทการออกกำลังกาย'].fillna('ไม่ได้ออกกำลังกาย',inplace=True) #แปลง NaN เป็น

# %%
csvdf.isnull().sum()
# Out:
# ประทับเวลา                                                                              0
# 1. เพศ                                                                                  0
# 2. อายุ                                                                                 0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ทานอาหารตามหลักโภชนาการ]                                 0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ดื่มน้ำเปล่าเพียงพอต่อความต้องการของร่างกาย]             0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [สูบบุหรี่หรือยาเส้น]                                     0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ดื่มแอลกอฮอล์หรือของมึนเมา]                              0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [คุณมีวิธีการจัดการกับความเครียด]                         0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [ล้างมือด้วยสบู่หลังการขับถ่าย]                           0
# ตอนที่2 พฤติกรรมการดูแลสุขภาพ [การตรวจสุขภาพประจำปี]                                    0
# ...

# %%
qmm =  pandasql.sqldf("select [2. ประเภทการออกกำลังกาย] from csvdf group by [2. ประเภทการออกกำลังกาย]")

qmm.head(30)
# Out:
#                               2. ประเภทการออกกำลังกาย
# 0                                         Body Weight
# 1                                             คาดิโอ้
# 2                                            คาร์ดิโอ
# 3                              ช่วงนี้ไม่ได้ออกเลยจ้า
# 4                                             ซิดอ้ัพ
# 5                                                 นอน
# 6   บ่าย 4 แกว่งแขน 30 นาที ทุกวัน เช้าปั่นจักรยาน...
# 7                                         ปั่นจักรยาน
# 8                                   ยกน้ำหนัก/เล่นเวท
# 9                                          วอลเลย์บอล
# 10                                               วิ่ง
# 11                                            ว่ายน้ำ
# 12                                           ฮูล่าฮูป
# 13                                               เดิน
# 14                                      เดินภายในบ้าน
# 15                   เดินวันละ 6,000-12,000ก้าวทุกวัน
# ...

# %%
csvdf['2. ประเภทการออกกำลังกาย'].replace({
        'คาดิโอ้':'คาร์ดิโอ',
        'ไม่ได้ออกกำลังเลย':'ไม่ได้ออกกำลังกาย',
        'ไม่ค่อยออก':'ไม่ได้ออกกำลังกาย',
        'ไม่ออก':'ไม่ได้ออกกำลังกาย',
        'ช่วงนี้ไม่ได้ออกเลยจ้า':'ไม่ได้ออกกำลังกาย'
      
    }, inplace=True)

# %%
qmm =  pandasql.sqldf("select [2. ประเภทการออกกำลังกาย] from csvdf group by [2. ประเภทการออกกำลังกาย]")

qmm.head(30)
# Out:
#                               2. ประเภทการออกกำลังกาย
# 0                                         Body Weight
# 1                                            คาร์ดิโอ
# 2                                             ซิดอ้ัพ
# 3                                                 นอน
# 4   บ่าย 4 แกว่งแขน 30 นาที ทุกวัน เช้าปั่นจักรยาน...
# 5                                         ปั่นจักรยาน
# 6                                   ยกน้ำหนัก/เล่นเวท
# 7                                          วอลเลย์บอล
# 8                                                วิ่ง
# 9                                             ว่ายน้ำ
# 10                                           ฮูล่าฮูป
# 11                                               เดิน
# 12                                      เดินภายในบ้าน
# 13                   เดินวันละ 6,000-12,000ก้าวทุกวัน
# 14                                           เดินเร็ว
# 15                                        เต้นแอโรบิค
# ...

# %%
csvdf.to_csv('ภูมิคุ้มกัน.csv')

# %%
qmm.to_csv('คอมเมนภูมิคุ้มกัน.csv')
